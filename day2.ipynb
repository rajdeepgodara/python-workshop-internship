# %%
mylist = [ "apple", "banana", "organe", "cherry", "blueberry"]

# %%
type(mylist)
# Out:
# list

# %%
mylist.remove("banana")

# %%
print(mylist)
# Out:
# ['apple', 'organe', 'cherry', 'blueberry']

# %%
mylist.append("orange")

# %%
print(mylist)
# Out:
# ['apple', 'organe', 'cherry', 'blueberry', 'orange']

# %%
mylist.sort()

# %%
mylist.count("apple")
# Out:
# 1

# %%
mylist.pop(1)
# Out:
# 'organe'

# %%
mylist.insert(1,"guvava")

# %%
print(mylist)
# Out:
# ['guvava', 'guvava']

# %%
mylist.clear()

# %%
print(mylist)
# Out:
# []

# %% [markdown]
# TUPPLE

# %%
mytuple = ("1", "2", "3", "1")
print(mytuple)
# Out:
# ('1', '2', '3', '1')

# %%
type(mytuple)
# Out:
# tuple

# %%
mytuple.index("1")
# Out:
# 0

# %%
mytuple.count("1")
# Out:
# 2

# %% [markdown]
# SET

# %%
setay = {1,2,3,4,5}

# %%
type(setay)
# Out:
# set

# %%
print(setay)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1,3}
set2 = {1,2,4}

# %%
print(set1 | set2)
# Out:
# {1, 2, 3, 4}

# %%
print( set1 & set2)
# Out:
# {1}

# %%
set1.clear()

# %%
print(set1)
# Out:
# set()

# %% [markdown]
# DICTIONARY

# %%
student = {"name":"Tom", "age":20}
student.items()
# Out:
# dict_items([('name', 'Tom'), ('age', 20)])

# %%
student.values()
# Out:
# dict_values(['Tom', 20])

# %%
print(student)
# Out:
# {'name': 'Tom', 'age': 20}

# %%
student.pop("name")
# Out:
# 'Tom'

# %%
print(student)
# Out:
# {'age': 20}

# %%
text = "Hello VGU "

# %%
print(text)
# Out:
# Hello VGU

# %%
print(text.find("VGU"))
# Out:
# 6

# %%
print(text.replace("VGU", "VGU GUYS"))
# Out:
# Hello VGU GUYS

# %%
text = "Hello VGU"
print(text.split())
# Out:
# ['Hello', 'VGU']

# %%
text2 = ("Hello", "VGU")

# %%
print(text2)
# Out:
# ('Hello', 'VGU')

# %%
print(" ".join(text2))
# Out:
# Hello VGU

# %%
file = open("Untitled.text" , "w")

# %%
file.close
# Out:
# <function TextIOWrapper.close()>

# %%
file.open
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 file.open
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'open'
