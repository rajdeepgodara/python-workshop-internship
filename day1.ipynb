# %%
print("hello")
# Out:
# hello

# %%
#hello this is a comment

# %% [markdown]
# Operators in Python

# %%
a = 1
b = 2

# %%
c = a + b

# %%
print (c)
# Out:
# 3

# %%
print (b-a)
# Out:
# 1

# %%
print (a ** b)
# Out:
# 1

# %%
print (a*b)
# Out:
# 2

# %% [markdown]
# Comparision Operators

# %%
a = 10
b = 5

# %%
print(b>a)
# Out:
# False

# %%
print(a==b)
# Out:
# False

# %%
print(a!=b)
# Out:
# True

# %% [markdown]
# Logical Operator

# %%
age = 18

# %%
print(age > 19 and age < 20)
# Out:
# False

# %%
print(age > 19 or age < 20)
# Out:
# True

# %% [markdown]
# Assignment Operator

# %%
x = 10

# %%
x += 2 # x = x + 2

# %%
print(x)
# Out:
# 12

# %% [markdown]
# Identity Operator

# %%
a = 1

# %%
b = a

# %%
print ( a is b)
# Out:
# True

# %% [markdown]
# PROJECT 1

# %%
num1 = float(input("enter your first number "))

# %%
num1 = float(input("enter your first number "))

# %%
num1 = float (input("enter your first number"))
num2 = float (input("enter your second number"))

print (f'first no is', (num1) , 'and second number is', (num2))
print ("Addition is: ", num1 + num2)
print ("Subtraction is: ", num1 - num2)
print ("Multiplication is: ", num1 * num2)
# Out:
# enter your first number 2
# enter your second number 2
# first no is 2.0 and second number is 2.0
# Addition is:  4.0
# Subtraction is:  0.0
# Multiplication is:  4.0

# %%
num1 = float(input("enter your first number "))

# %%
c = float(input("enter the temperature :"))
f = (( c * 1.8) + 32)
print("your temperature in F is ", f)
# Out:
# enter the temperature : 10
# your temperature in F is  50.0
