# %%
def print_name():
    print("TOM")

# %%
print_name()
# Out:
# TOM

# %%
def print_name(a):
    print(f'HI, {a}')

# %%
print_name("tom")
# Out:
# HI, tom

# %%
print_name("jack")
# Out:
# HI, jack

# %%
def multi_arg(*arg):
     print(arg)

# %%
multi_arg(1,2,3)
# Out:
# (1, 2, 3)

# %%
def add(a,b):
    print(a+b)

# %%
add(1,3)
# Out:
# 4

# %%
def tom_details():
    print(student)

# %%
def tom_details():  
    print()
    student(name = "Tom", contact = 123)

# %%
def myfunc(a,b):
    return a+b, a-b

# %%
myfunc(1,3)
# Out:
# (4, -2)

# %%
double = lambda x : x * 2

# %%
print (double(5))
# Out:
# 10

# %% [markdown]
# Import Tools

# %%
lpip install tools
# Out:
#   Cell In[54], line 1
#     lpip install tools
#          ^
# SyntaxError: invalid syntax

# %%
tools.greet("jack")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 tools.greet("jack")
#
# NameError: name 'tools' is not defined

# %% [markdown]
# import math

# %%
from math import sqrt

# %%
sqrt(25)
# Out:
# 5.0

# %%
sqrt(16)
# Out:
# 4.0

# %%
import random as r

# %%
r.randint(1,20)
# Out:
# 7

# %%
import datetime as d

# %%
print(d.datetime.today())
# Out:
# 2025-11-21 12:44:40.230836
